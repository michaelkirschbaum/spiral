# %%
'''
	Size = radius
	Each point is a position on the spiral
	Covers all of the indices around 0, 0
'''

import matplotlib.pyplot as plt
from math import sin, cos, pi

# create visualization of a spiral
def draw_spiral(size):
    plt.show()
    
draw_spiral(0)
